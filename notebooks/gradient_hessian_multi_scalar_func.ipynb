# %% [markdown]
# # Problem 1 - Gradient and Hessian of Multivariate Scalar Function
# From appendix `A.7 Exercises` page 65 in `Numerical Methods for Constrained Optimization`

# %% [markdown]
# Consider the function $f: \mathbb{R}^2 \mapsto \mathbb{R}$ defined by
# $$
# f(x)=x_1^2-2 x_1+3 x_1 x_2+4 x_2^3
# $$

# %%
def f(x1, x2):
    return x1**2 - 2*x1 + 2*x1*x2 + 4*x2**3

# %% [markdown]
# 1. Make a contour plot and approximately locate the minima.
# 2. Derive an analytical expression for the gradient, $\nabla f(x)$.
# 3. Derive an analytical expression for the Hessian, $\nabla^2 f(x)$
# 4. Implement a Matlab function for computation of $f(x), \nabla f(x)$, and $\nabla^2 f(x)$. The function must have the interface function $[\mathrm{f}, \mathrm{df}, \mathrm{d} 2 \mathrm{f}]=\operatorname{FunEx1}(\mathrm{x})$.
# 5. Use finite difference approximations to verify your expressions in the point $x_0=\left[\begin{array}{l}2 \\ 3\end{array}\right]$.

# %% [markdown]
# ## 1 - Contour Plot and Approx Minima Location

# %%
import numpy as np
from copti.plot.contour import plot_2d

x1 = np.linspace(-5, 5, 100)
x2 = np.linspace(-5, 5, 100)

plot_2d(f, x1, x2, save_path=None, show=True)

# %% [markdown]
# We see the 0-curve for the local minima
